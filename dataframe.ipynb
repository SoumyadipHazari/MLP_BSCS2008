# %%
import pandas as pd

# %%
data = {"State": ["Ohio", "Ohio", "Ohio", "Texas", "Texas", "Texas", "kolkata", "kolkata", "kolkata"], "Year": [2000,2001,2002,2001,2002,2003,2001,2002,2003], "PoP": [1.5,1.6,3.6,2.4,2.9,3.2,2.6,2.8,3.4]}

frame = pd.DataFrame(data)

# %%
frame
# Out:
#      State  Year  PoP
# 0     Ohio  2000  1.5
# 1     Ohio  2001  1.6
# 2     Ohio  2002  3.6
# 3    Texas  2001  2.4
# 4    Texas  2002  2.9
# 5    Texas  2003  3.2
# 6  kolkata  2001  2.6
# 7  kolkata  2002  2.8
# 8  kolkata  2003  3.4

# %%
frame.head()
# Out:
#    State  Year  PoP
# 0   Ohio  2000  1.5
# 1   Ohio  2001  1.6
# 2   Ohio  2002  3.6
# 3  Texas  2001  2.4
# 4  Texas  2002  2.9

# %%
frame.tail()
# Out:
#      State  Year  PoP
# 4    Texas  2002  2.9
# 5    Texas  2003  3.2
# 6  kolkata  2001  2.6
# 7  kolkata  2002  2.8
# 8  kolkata  2003  3.4

# %%
pd.DataFrame(data, columns = ["Year", "State", "PoP"])
# Out:
#    Year    State  PoP
# 0  2000     Ohio  1.5
# 1  2001     Ohio  1.6
# 2  2002     Ohio  3.6
# 3  2001    Texas  2.4
# 4  2002    Texas  2.9
# 5  2003    Texas  3.2
# 6  2001  kolkata  2.6
# 7  2002  kolkata  2.8
# 8  2003  kolkata  3.4

# %%
frame2 = pd.DataFrame(data, columns = ["Year", "State", "PoP", "debt"])

# %%
frame2
# Out:
#    Year    State  PoP debt
# 0  2000     Ohio  1.5  NaN
# 1  2001     Ohio  1.6  NaN
# 2  2002     Ohio  3.6  NaN
# 3  2001    Texas  2.4  NaN
# 4  2002    Texas  2.9  NaN
# 5  2003    Texas  3.2  NaN
# 6  2001  kolkata  2.6  NaN
# 7  2002  kolkata  2.8  NaN
# 8  2003  kolkata  3.4  NaN

# %%
frame2.columns
# Out:
# Index(['Year', 'State', 'PoP', 'debt'], dtype='str')

# %%
frame2.State
# Out:
# 0       Ohio
# 1       Ohio
# 2       Ohio
# 3      Texas
# 4      Texas
# 5      Texas
# 6    kolkata
# 7    kolkata
# 8    kolkata
# Name: State, dtype: str

# %%
frame2["State"]
# Out:
# 0       Ohio
# 1       Ohio
# 2       Ohio
# 3      Texas
# 4      Texas
# 5      Texas
# 6    kolkata
# 7    kolkata
# 8    kolkata
# Name: State, dtype: str

# %%
frame2.Year
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# 6    2001
# 7    2002
# 8    2003
# Name: Year, dtype: int64

# %%
frame2.loc[1]
# Out:
# Year     2001
# State    Ohio
# PoP       1.6
# debt      NaN
# Name: 1, dtype: object

# %%
frame2.loc[2]
# Out:
# Year     2002
# State    Ohio
# PoP       3.6
# debt      NaN
# Name: 2, dtype: object

# %%
frame2.loc[2,3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/Diploma_4th_term/Diploma_4th_term/Machine Learning Practice/.venv/lib64/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 frame2.loc[2,3]
#
# File ~/Documents/Diploma_4th_term/Diploma_4th_term/Machine Learning Practice/.venv/lib64/python3.14/site-packages/pandas/core/indexing.py:1199, in _LocationIndexer.__getitem__(self, key)
#    1197     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1198     if self._is_scalar_access(key):
# -> 1199         return self.obj._get_value(*key, takeable=self._takeable)
#    1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#
# File ~/Documents/Diploma_4th_term/Diploma_4th_term/Machine Learning Practice/.venv/lib64/python3.14/site-packages/pandas/core/frame.py:4489, in DataFrame._get_value(self, index, col, takeable)
#    4485         if takeable:
#    4486             series = self._ixs(col, axis=1)
#    4487             return series._values[index]
#    4488
# -> 4489         series = self._get_item(col)
#    4490
#    4491         if not isinstance(self.index, MultiIndex):
#    4492             # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#
# File ~/Documents/Diploma_4th_term/Diploma_4th_term/Machine Learning Practice/.venv/lib64/python3.14/site-packages/pandas/core/frame.py:4967, in DataFrame._get_item(self, item)
#    4966     def _get_item(self, item: Hashable) -> Series:
# -> 4967         loc = self.columns.get_loc(item)
#    4968         return self._ixs(loc, axis=1)
#
# File ~/Documents/Diploma_4th_term/Diploma_4th_term/Machine Learning Practice/.venv/lib64/python3.14/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 3

# %%
frame2.iloc[2,3]

# %%
frame2.iloc[2,1]

# %%
frame2["debt"] = "13M"

# %%
frame2

# %%
frame2["debt"] = [45,2,3,4,51,45,2,1,53]

# %%
frame2
# Out:
#    Year    State  PoP  debt
# 0  2000     Ohio  1.5    45
# 1  2001     Ohio  1.6     2
# 2  2002     Ohio  3.6     3
# 3  2001    Texas  2.4     4
# 4  2002    Texas  2.9    51
# 5  2003    Texas  3.2    45
# 6  2001  kolkata  2.6     2
# 7  2002  kolkata  2.8     1
# 8  2003  kolkata  3.4    53

# %%
frame2["debt"] = [45,2,3,4,51,45,2,1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 frame2["debt"] = [45,2,3,4,51,45,2,1]
#
# File ~/Documents/Diploma_4th_term/Diploma_4th_term/Machine Learning Practice/.venv/lib64/python3.14/site-packages/pandas/core/frame.py:4672, in DataFrame.__setitem__(self, key, value)
#    4668             # Column to set is duplicated
#    4669             self._setitem_array([key], value)
#    4670         else:
#    4671             # set column
# -> 4672             self._set_item(key, value)
#
# File ~/Documents/Diploma_4th_term/Diploma_4th_term/Machine Learning Practice/.venv/lib64/python3.14/site-packages/pandas/core/frame.py:4872, in DataFrame._set_item(self, key, value)
#    4868
#    4869         Series/TimeSeries will be conformed to the DataFrames index to
#    4870         ensure homogeneity.
#    4871         """
# -> 4872         value, refs = self._sanitize_column(value)
#    4873
#    4874         if (
#    4875             key in self.columns
#
# File ~/Documents/Diploma_4th_term/Diploma_4th_term/Machine Learning Practice/.venv/lib64/python3.14/site-packages/pandas/core/frame.py:5754, in DataFrame._sanitize_column(self, value)
#    5750                 value = Series(value)
#    5751             return _reindex_for_setitem(value, self.index)
#    5752
#    5753         if is_list_like(value):
# -> 5754             com.require_length_match(value, self.index)
#    5755         return sanitize_array(value, self.index, copy=True, allow_2d=True), None
#
# File ~/Documents/Diploma_4th_term/Diploma_4th_term/Machine Learning Practice/.venv/lib64/python3.14/site-packages/pandas/core/common.py:601, in require_length_match(data, index)
#     597 """
#     598 Check the length of data matches the length of the index.
#     599 """
#     600 if len(data) != len(index):
# --> 601     raise ValueError(
#     602         "Length of values "
#     603         f"({len(data)}) "
#     604         "does not match length of index "
#     605         f"({len(index)})"
#     606     )
#
# ValueError: Length of values (8) does not match length of index (9)

# %%
 val = pd.Series([-1.2, -1.5, -1.7], index=["two", "four", "five"])

# %%
frame2["debt"] = val

# %%
frame2
# Out:
#    Year    State  PoP  debt
# 0  2000     Ohio  1.5   NaN
# 1  2001     Ohio  1.6   NaN
# 2  2002     Ohio  3.6   NaN
# 3  2001    Texas  2.4   NaN
# 4  2002    Texas  2.9   NaN
# 5  2003    Texas  3.2   NaN
# 6  2001  kolkata  2.6   NaN
# 7  2002  kolkata  2.8   NaN
# 8  2003  kolkata  3.4   NaN

# %%
 val = pd.Series([-1.2, -1.5, -1.7], index=[2,4,5])

# %%
frame2["debt"] = val

# %%
frame2
# Out:
#    Year    State  PoP  debt
# 0  2000     Ohio  1.5   NaN
# 1  2001     Ohio  1.6   NaN
# 2  2002     Ohio  3.6  -1.2
# 3  2001    Texas  2.4   NaN
# 4  2002    Texas  2.9  -1.5
# 5  2003    Texas  3.2  -1.7
# 6  2001  kolkata  2.6   NaN
# 7  2002  kolkata  2.8   NaN
# 8  2003  kolkata  3.4   NaN

# %%
frame2["eastern"] = frame2["State"] == "Ohio"

# %%
frame2
# Out:
#    Year    State  PoP  debt  eastern
# 0  2000     Ohio  1.5   NaN     True
# 1  2001     Ohio  1.6   NaN     True
# 2  2002     Ohio  3.6  -1.2     True
# 3  2001    Texas  2.4   NaN    False
# 4  2002    Texas  2.9  -1.5    False
# 5  2003    Texas  3.2  -1.7    False
# 6  2001  kolkata  2.6   NaN    False
# 7  2002  kolkata  2.8   NaN    False
# 8  2003  kolkata  3.4   NaN    False

# %%
frame2.State
# Out:
# 0       Ohio
# 1       Ohio
# 2       Ohio
# 3      Texas
# 4      Texas
# 5      Texas
# 6    kolkata
# 7    kolkata
# 8    kolkata
# Name: State, dtype: str

# %%
frame2.eastern
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# Name: eastern, dtype: bool

# %%
del frame2["eastern"]

# %%
frame2.columns
# Out:
# Index(['Year', 'State', 'PoP', 'debt'], dtype='str')
