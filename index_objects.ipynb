# %%
import pandas as pd

# %%
import numpy as np

# %%
obj = pd.Series(np.arange(3), index = ["b", "a", "c"])

# %%
index = obj.index

# %%
index
# Out:
# Index(['b', 'a', 'c'], dtype='str')

# %%
index[1:]
# Out:
# Index(['a', 'c'], dtype='str')

# %%
index[1] = "b"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 index[1] = "b"
#
# File ~/Documents/Diploma_4th_term/Diploma_4th_term/Machine Learning Practice/.venv/lib64/python3.14/site-packages/pandas/core/indexes/base.py:5382, in Index.__setitem__(self, key, value)
#    5380 @final
#    5381 def __setitem__(self, key, value) -> None:
# -> 5382     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
labels = pd.Index(np.arange(4))

# %%
labels
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
content = pd.Index([1,3,5,7])

# %%
obj2 = pd.Series([1.2,3.4,-5.6,2.1], index = content)

# %%
obj2
# Out:
# 1    1.2
# 3    3.4
# 5   -5.6
# 7    2.1
# dtype: float64

# %%
obj2.index is labels
# Out:
# False

# %%
frame3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 frame3
#
# NameError: name 'frame3' is not defined

# %%
population = {"ohio": {2000: 1.5, 2001:1.7, 2002:3.6}, "navada": {2001:2.4,2002:2.9}}

# %%
frame3 = pd.DataFrame(population)

# %%
frame3
# Out:
#       ohio  navada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
frame3.index.name = "year"
frame3.columns.name =  "state"

# %%
frame3
# Out:
# state  ohio  navada
# year
# 2000    1.5     NaN
# 2001    1.7     2.4
# 2002    3.6     2.9

# %%
frame3.columns
# Out:
# Index(['ohio', 'navada'], dtype='str', name='state')

# %%
frame3.index
# Out:
# Index([2000, 2001, 2002], dtype='int64', name='year')

# %%
pd.Index(["foo","foo","faa","faa"])
# Out:
# Index(['foo', 'foo', 'faa', 'faa'], dtype='str')
